# %% [markdown]
# <a href="https://colab.research.google.com/github/sadashish2002/DSA-Problem-using-Python-/blob/main/Copy_of_Indexing_%26_Slicing_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###1. Imagine that you are a superhero movie buff and you're trying to create a list of the most iconic Marvel characters. You have compiled a list of some of the most popular characters, but you want to narrow it down to the top 6.
#
# Here's your list of characters:
#
# marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %%
# Here's your list of characters:

marvel_words = ['Avengers', 'X-Men', 'Spider-Man', 'Iron Man', 'Hulk', 'Thor', 'Black Widow', 'Captain America', 'Wolverine', 'Doctor Strange', 'Namor']

# %% [markdown]
# You want to narrow down the list to the last 6 characters in the list. These characters are:
#
# * Namor
# * Doctor Strange
# * Wolverine
# * Captain America
# * Black Widow
# * Thor

# %% [markdown]
# Write a code to slice these characters from the list

# %%
# Replace x with appropriate values
new_marvel=marvel_words[5:11] 
new_marvel[::-1]
# Out:
# ['Namor',
#  'Doctor Strange',
#  'Wolverine',
#  'Captain America',
#  'Black Widow',
#  'Thor']

# %% [markdown]
# ###2. Create two teams of superheroes based on their index position: one team should consist of all the characters located at even index positions, while the other team should consist of all the characters located at odd index positions.

# %%
team1=marvel_words[0::2]   #Add appropriate index and step size
team2=marvel_words[1::2]   #Add appropriate index and step size
print(team1)
print(team2)
# Out:
# ['Avengers', 'Spider-Man', 'Hulk', 'Black Widow', 'Wolverine', 'Namor']
# ['X-Men', 'Iron Man', 'Thor', 'Captain America', 'Doctor Strange']

# %% [markdown]
# ###3. Store the word 'Spider-Man' in a new variable, and slice the word 'Spider' from it.

# %%
spider_man=marvel_words[2] # Add appropriate index number 
spidey_sliced=spider_man[0:6] # Add appropriate index number
print(spidey_sliced)
# Out:
# Spider

# %% [markdown]
# ###4. Store the word 'Iron-Man' in a variable and use reverse indexing to reverse it.

# %%
#Your code here
iron_man=marvel_words[3]
reversed_man=iron_man[::-1]
print(reversed_man)
# Out:
# naM norI
